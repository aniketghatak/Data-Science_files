# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"D:\Data Analysis Projects\DS_Playlist\datasets\HousingData.csv")
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
input_data=dataset.iloc[:,:-1]
input_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90    NaN
# ..       ...     ...    ...
# 501     21.0  391.99    NaN
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
output_data=dataset["MEDV"]
output_data
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(input_data,output_data,test_size=0.25)

# %%
x_test
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 380  88.97620   0.0  18.10   0.0  0.671  6.968  91.9  1.4165   24  666
# 475   6.39312   0.0  18.10   0.0  0.584  6.162  97.4  2.2060   24  666
# 501   0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 60    0.14932  25.0   5.13   0.0  0.453  5.741  66.2  7.2254    8  284
# 289   0.04297  52.5   5.32   0.0  0.405  6.565  22.9  7.3172    6  293
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 98    0.08187   0.0   2.89   0.0  0.445  7.820  36.9  3.4952    2  276
# 210   0.17446   NaN  10.59   1.0  0.489  5.960  92.1  3.8771    4  277
# 7     0.14455  12.5   7.87   0.0  0.524  6.172  96.1  5.9505    5  311
# 214   0.28955   0.0  10.59   0.0  0.489  5.412   9.8  3.5875    4  277
# 272   0.11460  20.0   6.96   0.0  0.464  6.538  58.7  3.9175    3  223
#
#      PTRATIO       B  LSTAT
# 380     20.2  396.90  17.21
# 475     20.2  302.76  24.10
# 501     21.0  391.99    NaN
# 60      19.7  395.11  13.15
# 289     16.6  371.72   9.51
# ..       ...     ...    ...
# 98      18.0  393.53   3.57
# 210     18.6  393.25  17.27
# 7       15.2  396.90  19.15
# 214     18.6  348.93  29.55
# 272     18.6  394.96   7.73
#
# [127 rows x 13 columns]

# %%
x_train
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD  TAX  \
# 20   1.25179   0.0   8.14   0.0  0.5380  5.570  98.1  3.7979    4  307
# 504  0.10959   0.0  11.93   0.0  0.5730  6.794  89.3  2.3889    1  273
# 28   0.77299   0.0   8.14   0.0  0.5380  6.495  94.4  4.4547    4  307
# 204  0.02009  95.0   2.68   0.0  0.4161  8.034  31.9  5.1180    4  224
# 62   0.11027  25.0   5.13   0.0  0.4530  6.456  67.8  7.2255    8  284
# ..       ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 327  0.24103   0.0   7.38   0.0  0.4930  6.083  43.7  5.4159    5  287
# 4    0.06905   0.0   2.18   0.0  0.4580  7.147  54.2  6.0622    3  222
# 85   0.05735   0.0   4.49   0.0  0.4490  6.630  56.1  4.4377    3  247
# 497  0.26838   0.0   9.69   0.0  0.5850  5.794  70.6  2.8927    6  391
# 34   1.61282   0.0   8.14   0.0  0.5380  6.096  96.9  3.7598    4  307
#
#      PTRATIO       B  LSTAT
# 20      21.0  376.57  21.02
# 504     21.0  393.45   6.48
# 28      21.0  387.94  12.80
# 204     14.7  390.55   2.88
# 62      19.7  396.90   6.73
# ..       ...     ...    ...
# 327     19.6  396.90  12.79
# 4       18.7  396.90    NaN
# 85      18.5  392.30   6.53
# 497     19.2  396.90  14.10
# 34      21.0  248.31  20.34
#
# [379 rows x 13 columns]

# %%
y_test
# Out:
# 380    10.4
# 475    13.3
# 501    22.4
# 60     18.7
# 289    24.8
#        ...
# 98     43.8
# 210    21.7
# 7      27.1
# 214    23.7
# 272    24.4
# Name: MEDV, Length: 127, dtype: float64

# %%
y_test
# Out:
# 380    10.4
# 475    13.3
# 501    22.4
# 60     18.7
# 289    24.8
#        ...
# 98     43.8
# 210    21.7
# 7      27.1
# 214    23.7
# 272    24.4
# Name: MEDV, Length: 127, dtype: float64

# %%
dataset.shape
# Out:
# (506, 14)

# %%
x_train.shape, x_test.shape
# Out:
# ((379, 13), (127, 13))

# %%
y_train.shape, y_test.shape
# Out:
# ((379,), (127,))
