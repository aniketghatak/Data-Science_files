# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"D:\Data Analysis Projects\DS_Playlist\datasets\Salary_Data.csv")
dataset.head()
# Out:
#     Age  Experience  Salary
# 0  21.0         1.1   39343
# 1  21.5         1.3   46205
# 2  21.7         1.5   37731
# 3  22.0         2.0   43525
# 4  22.2         2.2   39891

# %%
dataset.shape
# Out:
# (30, 3)

# %%
dataset.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 88.52101657216535

# %%
lr.coef_
# Out:
# array([2567.51865301, 4882.14850701])

# %%
lr.intercept_
# Out:
# -20612.691921485282

# %%
x.columns
# Out:
# Index(['Age', 'Experience'], dtype='object')

# %%
lr.predict(x_test)
# Out:
# array([118686.60525402,  67497.80208802, 101581.52273219,  74585.69879684,
#         54833.367916  ,  58044.6977654 ])
